# %% [markdown]
# Knowledge Check 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("assets\SalaryData.csv", nrows=40000)
plt.style.use('fivethirtyeight')
df['Annual_Rate'].hist(bins=100, edgecolor='black')
plt.title('Salaries of Louisville City Government Workers')
plt.xlabel('Salaries')
plt.ylabel('Number of Workers')
# Out:
# Text(0, 0.5, 'Number of Workers')
